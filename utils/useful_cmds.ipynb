# %%
# %%bash
# # below command line can print out the detailed status of my graphics card
# nvidia-smi
# Out:
# Sun Sep 29 22:27:27 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.02              Driver Version: 555.42.02      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4090        Off |   00000000:01:00.0  On |                  Off |
# |  0%   38C    P8              9W /  450W |     920MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %%bash
# # below command ranks the processes with highest memory consumption
# ps aux --sort=-%mem
# Out:
# USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# ...

# %%
# %%bash
# # kill the pid for jupyter runtime (the process with '...jupyter/runtime/kernel...') to release the GPU memory
# kill -9 84292
